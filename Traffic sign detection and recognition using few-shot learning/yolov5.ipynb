# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/AI_CAPSTONE_PROJECT/Code/yolov5.zip -d /content/yolov5
# Out:
# Archive:  /content/drive/MyDrive/AI_CAPSTONE_PROJECT/Code/yolov5.zip
#   inflating: /content/yolov5/yolov5/.dockerignore
#    creating: /content/yolov5/yolov5/.git/
#    creating: /content/yolov5/yolov5/.git/branches/
#   inflating: /content/yolov5/yolov5/.git/config
#   inflating: /content/yolov5/yolov5/.git/description
#   inflating: /content/yolov5/yolov5/.git/FETCH_HEAD
#  extracting: /content/yolov5/yolov5/.git/HEAD
#    creating: /content/yolov5/yolov5/.git/hooks/
#   inflating: /content/yolov5/yolov5/.git/hooks/applypatch-msg.sample
#   inflating: /content/yolov5/yolov5/.git/hooks/commit-msg.sample
#   inflating: /content/yolov5/yolov5/.git/hooks/fsmonitor-watchman.sample
#   inflating: /content/yolov5/yolov5/.git/hooks/post-update.sample
#   inflating: /content/yolov5/yolov5/.git/hooks/pre-applypatch.sample
#   inflating: /content/yolov5/yolov5/.git/hooks/pre-commit.sample
#   inflating: /content/yolov5/yolov5/.git/hooks/pre-merge-commit.sample
# ...

# %%
# %pip install -qr /content/yolov5/yolov5/requirements.txt  # install
# !pip install utils
import torch
import utils
#display = utils.notebook_init()  # checks
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python /content/yolov5/yolov5/train.py --img 640 --batch 15 --epochs 50 --data /content/yolov5/yolov5/data/custom_data.yaml --weights /content/yolov5/yolov5/runs/train/exp3/weights/best.pt --cache
# Out:
# 2023-04-12 15:53:47.944529: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-12 15:53:49.775842: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !python /content/yolov5/yolov5/detect.py --weights /content/yolov5/yolov5/runs/train/exp4/weights/best.pt --img 640 --conf 0.25 --source /content/232.png --save-crop
# Out:
# detect: weights=['/content/yolov5/yolov5/runs/train/exp4/weights/best.pt'], source=/content/232.png, data=yolov5/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-131-g0c8de3f Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7088338 parameters, 0 gradients, 16.0 GFLOPs
# image 1/1 /content/232.png: 256x640 1 no car entry/turning, 1 direction, 2 speed limits, 1 vehicle permission lane, 41.5ms
# Speed: 0.4ms pre-process, 41.5ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/yolov5/runs/detect/exp5

# %%
# !zip -r /content/yolov5.zip /content/yolov5
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/yolov5/ (stored 0%)
#   adding: content/yolov5/yolov5/runs/ (stored 0%)
#   adding: content/yolov5/yolov5/runs/train/ (stored 0%)
#   adding: content/yolov5/yolov5/runs/train/exp2/ (stored 0%)
#   adding: content/yolov5/yolov5/runs/train/exp2/events.out.tfevents.1681311588.3e864c293d72.5244.0 (deflated 9%)
#   adding: content/yolov5/yolov5/runs/train/exp2/hyp.yaml (deflated 45%)
#   adding: content/yolov5/yolov5/runs/train/exp2/weights/ (stored 0%)
#   adding: content/yolov5/yolov5/runs/train/exp2/opt.yaml (deflated 51%)
#   adding: content/yolov5/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/yolov5/runs/train/exp/events.out.tfevents.1679993580.b8615d6503ce.1445.0 (deflated 5%)
#   adding: content/yolov5/yolov5/runs/train/exp/hyp.yaml (deflated 45%)
#   adding: content/yolov5/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/yolov5/yolov5/runs/train/exp/opt.yaml (deflated 49%)
# ...
